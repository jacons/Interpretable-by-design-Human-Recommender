# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from Class_utils.parameters import file_paths,job_graph_par
from Class_utils.JobGraph import JobGraph
import ast
from Class_utils.FitnessFunctions import FitnessFunctions

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")
# %reload_ext autoreload
# %autoreload 2

# %%
job_graph = JobGraph(file_paths, **job_graph_par)
# Out:
# Cache found loading...done

# %%
curricula = pd.read_csv("../outputs/test20k_curricula.csv").set_index("kId")

# %%
curricula
# Out:
#        qId                                           metadata    Education  \
# kId
# 0        0  {'occ': '61d9270c-491d-438d-8d41-77ba2e0ef023'...    Master-D.
# 1        0  {'occ': '61d9270c-491d-438d-8d41-77ba2e0ef023'...    Master-D.
# 2        0  {'occ': 'c5b45ebe-0e9f-4bc4-9563-7fdf31115e53'...    Master-D.
# 3        0  {'occ': 'b0ad8659-0410-4b5b-9466-a90f8b3cdac9'...    Master-D.
# 4        0  {'occ': 'b0ad8659-0410-4b5b-9466-a90f8b3cdac9'...    Master-D.
# ...    ...                                                ...          ...
# 19829  199  {'occ': 'a99b38bc-6e71-4bef-b127-0f2b5e357815'...       Degree
# 19830  199  {'occ': '4e3fede9-5522-4624-91bc-b59c79fada02'...    Master-D.
# 19831  199  {'occ': '8908d5aa-ac58-465e-9b75-7e02ed4af3a9'...       Degree
# 19832  199  {'occ': '3c305542-a51b-4b96-8d45-af11ca05eaa2'...  Bachelor-D.
# 19833  199  {'occ': '74332fd0-4a50-464e-9116-98fa9b8127ac'...       Degree
#
#        Age                       City  JobRange  \
# kId
# 0       27  San Giovanni in Persiceto        50
# 1       30          Castro dei Volsci        70
# 2       31                  Mezzanino        80
# 3       27                Sant'Arpino        80
# 4       28       Robecco sul Naviglio        80
# ...    ...                        ...       ...
# 19829   26                  Comacchio        30
# 19830   40                      Pavia        30
# 19831   43          Savoia di Lucania        70
# 19832   36                     Locana        90
# 19833   21                     Latina        30
#
#                                        Competences0  \
# kId
# 0                          write inspection reports
# 1                       write an evaluation reports
# 2                             use testing equipment
# 3                          write inspection reports
# 4                          write inspection reports
# ...                                             ...
# 19829                               train employees
# 19830                         deal with CAE systems
# 19831  oversee software systems used in dispatching
# 19832                        prepare lesson content
# 19833     respond to electrical power contingencies
#
#                                        Competences1  \
# kId
# 0      revise quality control systems documentation
# 1      revise quality control systems documentation
# 2      extract information from standard blueprints
# 3      revise quality control systems documentation
# 4                            assembly line teamwork
# ...                                             ...
# 19829                    perform project management
# 19830                            apply CAD software
# 19831                   collaborate with port users
# 19832                  perform classroom management
# 19833                  inspect overhead power lines
#
#                                             Competences2  \
# kId
# 0                               read standard blueprints
# 1             manufacturing quality standards monitoring
# 2      manage compliance with health, safety, and hyg...
# 3      ensure compliance with health, safety, and hyg...
# 4      support implementation of quality management s...
# ...                                                  ...
# 19829                    manage keys for data protection
# 19830                  erect the controller of a machine
# 19831  implement cost-effective cargo handling strate...
# 19832        communicate with a non-scientific audience
# 19833  ensure compliance with electricity distributio...
#
#                                       Competences3  ...  \
# kId                                                 ...
# 0                      negotiate with stakeholders  ...
# 1               manage health and safety standards  ...
# 2                     coordinate performance tests  ...
# 3                                                -  ...
# 4      amend quality control systems documentation  ...
# ...                                            ...  ...
# 19829                implement ICT risk management  ...
# 19830                 prepare production processes  ...
# 19831      ensure compliance with port regulations  ...
# 19832                              assess students  ...
# 19833          adapt energy distribution schedules  ...
#
#                                    Knowledge4                  Knowledge5  \
# kId
# 0                                           -                           -
# 1           continuous improvement strategies                           -
# 2                   principles of electricity                           -
# 3                                           -                           -
# 4                                           -                           -
# ...                                       ...                         ...
# 19829            ICT system user requirements  ICT network security risks
# 19830                              schematics                           -
# 19831  maritime telecommunications operations   freight transport methods
# 19832              animal reproductive system   animal production science
# 19833                    electrical discharge                           -
#
#       Knowledge6 Language0 Language1 Language2 Language_level0  \
# kId
# 0              -   Spanish    German   English            Null
# 1              -    German   English         -              A1
# 2              -   Italian    German   English              C2
# 3              -   Italian   English         -            Null
# 4              -    German   English         -            Null
# ...          ...       ...       ...       ...             ...
# 19829          -   Italian    German    French              C1
# 19830          -   Italian    French         -              C2
# 19831          -   Spanish    French   English              B2
# 19832          -   Spanish   Italian    French              A2
# 19833          -   Chinese         -         -            Null
#
#       Language_level1 Language_level2 Experience
# kId
# 0                  A1              C2          1
# 1                  C2               -          0
# 2                Null              C1          1
# 3                  C2               -          1
# 4                  C2               -          0
# ...               ...             ...        ...
# 19829            Null            Null          3
# 19830              B2               -          1
# 19831            Null            Null          1
# 19832            Null            Null          1
# 19833               -               -          0
#
# [19834 rows x 27 columns]

# %%
curricula_md = pd.json_normalize(curricula["metadata"].apply(ast.literal_eval))
curricula_md.index.rename("kId", inplace=True)

# %%
comp_columns = ["Competences"+str(i) for i in range(0, 6 + 1)]
know_columns = ["Knowledge"+str(i) for i in range(0, 6 + 1)]

# %%
counter = np.zeros((2, 5))
total = np.zeros((2, 5))
qId_error_comp,qId_error_know = [],[]


for kId, cv in tqdm(curricula.iterrows(),total=len(curricula)):

    comp = FitnessFunctions.filter(cv[comp_columns].to_list())
    un_comp, amb_comp = job_graph.skill_standardize(comp)
    de_amb_comp = job_graph.solve_ambiguous(amb_comp, un_comp)
    
    real_uris = curricula_md.loc[kId, "uri_competences"]
    total[0, len(amb_comp)] += 1
    equal_ = 0 if set(un_comp) | set(de_amb_comp)  ==  set(real_uris) else 1
    if equal_ == 1:
        counter[0, len(amb_comp)] += 1
        qId_error_comp.append(kId)

    know = FitnessFunctions.filter(cv[know_columns].to_list())
    un_know, amb_know = job_graph.skill_standardize(know)
    de_amb_know = job_graph.solve_ambiguous(amb_know, un_know)

    real_uris = curricula_md.loc[kId, "uri_knowledge"]
    total[1, len(amb_know)] += 1
    equal_ = 0 if set(un_know) | set(de_amb_know)  ==  set(real_uris) else 1
    if equal_ == 1:
        counter[1, len(amb_know)] += 1
        qId_error_know.append(kId)
# Out:
# 100%|██████████| 19834/19834 [01:16<00:00, 260.05it/s]

# %%
counter
# Out:
# array([[  0., 239.,  61.,   7.,   0.],
#        [  0., 600., 128.,  33.,   1.]])

# %%
total
# Out:
# array([[1.6456e+04, 3.0500e+03, 3.0500e+02, 2.2000e+01, 1.0000e+00],
#        [1.5667e+04, 3.7530e+03, 3.6500e+02, 4.8000e+01, 1.0000e+00]])

# %%
total_, errors_ = list(total.sum(axis=0)), list(counter.sum(axis=0))
dt = pd.DataFrame(
    {
        "# ambiguous":[*range(len(errors_))],
        "perc": [e/t if t > 0 else 0 for t, e in zip(total_,errors_)],
        "%": [str(format(e/t, '.4f'))+" %" if t > 0 else "0.0000 %" for t, e in zip(total_,errors_)]
    })
dt.drop(0,inplace=True)
dt
# Out:
#    # ambiguous      perc         %
# 1            1  0.123328  0.1233 %
# 2            2  0.282090  0.2821 %
# 3            3  0.571429  0.5714 %
# 4            4  0.500000  0.5000 %

# %%
_, axs = plt.subplots(figsize=(10, 7))

sns.barplot(x="# ambiguous", y="perc", palette="flare",data=dt, ax=axs)
sns.despine(left=True, bottom=True)
axs.set_title('Number of disambiguation errors in curricula', fontsize=18)
axs.set_xlabel('Number of ambiguous skills', fontsize=16)
axs.set_ylabel('Disambiguation Errors', fontsize=16)
axs.tick_params(axis='both', labelsize=14)
axs.set_ylim([0, 1])

table = plt.table(cellText=dt[["# ambiguous","%"]].values, colLabels=dt[["# ambiguous","%"]].columns,
                  cellLoc='center', bbox=[0.05, 0.5, 0.35, 0.4], loc='upper right')

table.auto_set_font_size(False)
table.set_fontsize(16)
plt.show()

# %%
# iiid = 171
# 
# essential_comp = FitnessFunctions.filter(offer.loc[iiid][es_comp_columns].to_list())
# print("Essential competence",essential_comp,"\n")
# optional_comp = FitnessFunctions.filter(offer.loc[iiid][op_comp_columns].to_list())
# print("Optional competence",optional_comp,"\n")
# essential_know = FitnessFunctions.filter(offer.loc[iiid][es_know_columns].to_list())
# print("Essential knowledge",essential_know,"\n")
# optional_know = FitnessFunctions.filter(offer.loc[iiid][op_know_columns].to_list())
# print("Optional knowledge", optional_know,"\n")
# 
# un_es_comp, amb_es_comp = job_graph.skill_standardize(essential_comp)
# un_op_comp, amb_op_comp = job_graph.skill_standardize(optional_comp)
# un_es_know, amb_es_know = job_graph.skill_standardize(essential_know)
# un_op_know, amb_op_know = job_graph.skill_standardize(optional_know)
# 
# contex = set(un_es_comp) | set(un_op_comp) | set(un_es_know) | set(un_op_know)
# 
# print("unique",un_es_comp,"\n")
# 
# print("ambigue",amb_es_comp,"\n")
# 
# deamb_es_comp = job_graph.solve_ambiguation(amb_es_comp, un_es_comp, True)
# # print("node similarity", job_graph.node_similarity(amb_op_comp[0], contex,True))
# 
# print("deambigued",deamb_es_comp,"\n")
# real_uri = offer_md.loc[iiid, "uri_competence_essential"]
# print("real",real_uri,"\n")
# print(set(un_es_comp) | set(deamb_es_comp) == set(real_uri))
# # essential_comp = FitnessFunctions.filter(job[es_comp_columns].to_list())
# # optional_comp = FitnessFunctions.filter(job[op_comp_columns].to_list())
# # essential_know = FitnessFunctions.filter(job[es_know_columns].to_list())
# # optional_know = FitnessFunctions.filter(job[op_know_columns].to_list())
