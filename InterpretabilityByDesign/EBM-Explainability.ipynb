# %%
import numpy as np
import pandas as pd
from InterpretabilityByDesign.EBM_Interpreter import ExplainableBMInterpreter
import matplotlib.pyplot as  plt
import seaborn as sns
from Class_utils.parameters import matching_par

sns.set_style("darkgrid")
import warnings
warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")
# %reload_ext autoreload
# %autoreload 2

# %%
interpreter = ExplainableBMInterpreter('./../Models/GlassBox/ebm/saved_models/EBM_Interpreter')

# %% [markdown]
# ## fitness education

# %%
edu_basic_points = interpreter.build_dataframe_function("fitness_edu_basic")
edu_bonus_points = interpreter.build_dataframe_function("fitness_edu_bonus")

# %%
_, axs = plt.subplots(ncols=2,figsize=(12,4))

sns.barplot(x="x",y="y", data=edu_basic_points, palette="flare", hue="y", legend=False, width=0.3, ax=axs[0])
axs[0].axhline(y=0, color="black", linestyle="-",linewidth=0.5)
axs[0].set_yticks([*np.arange(-8,6)])
axs[0].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[0].set_xlabel("")
axs[0].set_ylabel("Contribute", fontsize=15)
axs[0].set_title("Education essential")
axs[0].set_xticks([0, 1],["not satisfy","satisfy"],fontsize=14)

sns.barplot(x="x",y="y",data=edu_bonus_points, palette="flare", hue="y", legend=False, width=0.3, ax=axs[1])
axs[1].axhline(y=0,color="black",linestyle="-",linewidth=0.5)
axs[1].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[1].set_xlabel("")
axs[1].set_ylabel("Contribute", fontsize=15)
axs[1].set_title("Education optional")
axs[1].set_xticks([0, 1],["not satisfy","satisfy"], fontsize=14)
axs[1].set_yticks(axs[0].get_yticks())
plt.suptitle("Education feature",fontsize=18)
plt.show()

# %% [markdown]
# ## fitness city and age

# %%
city_points = interpreter.build_dataframe_function("fitness_city")
age_points = interpreter.build_dataframe_function("fitness_age")

_, axs = plt.subplots(ncols=2,figsize=(12,4))

sns.barplot(x="x",y="y", data=city_points, palette="flare",hue="y", legend=False, width=0.3, ax=axs[0])
axs[0].axhline(y=0,color="black",linestyle="-",linewidth=0.5)
axs[0].set_yticks([*np.arange(-3,4, 0.5)])
axs[0].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[0].set_xlabel("")
axs[0].set_ylabel("Contribute", fontsize=15)
axs[0].set_title("Range")
axs[0].set_xticks([0, 1, 2],["out of\nrange","almost in\nrange","in range"],fontsize=14)

sns.barplot(x="x",y="y",data=age_points,  palette="flare",hue="y", legend=False,width=0.3, ax=axs[1])
axs[1].axhline(y=0,color="black",linestyle="-",linewidth=0.5)
axs[1].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[1].set_xlabel("")
axs[1].set_ylabel("Contribute", fontsize=15)
axs[1].set_title("Age")
axs[1].set_xticks([0, 1],["not satisfy","satisfy"],fontsize=14)
axs[1].set_yticks(axs[0].get_yticks())
plt.suptitle("City/Age features",fontsize=18)
plt.show()

# %% [markdown]
# ## fitness experience

# %%
exp_basic_points = interpreter.build_dataframe_function("fitness_exp_basic")
exp_bonus_points = interpreter.build_dataframe_function("fitness_exp_bonus")

_, axs = plt.subplots(ncols=2, figsize=(12, 4))

sns.barplot(x="x", y="y", data=exp_basic_points, palette="flare", hue="y", legend=False,width=0.3, ax=axs[0])
axs[0].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[0].set_yticks([*np.arange(-4, 7, 0.5)])
axs[0].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[0].set_xlabel("")
axs[0].set_ylabel("Contribute", fontsize=15)
axs[0].set_title("Experience essential")
axs[0].set_xticks([0, 1], ["not satisfy", "satisfy"],fontsize=14)

sns.barplot(x="x", y="y", data=exp_bonus_points, palette="flare", hue="y", legend=False,width=0.3, ax=axs[1])
axs[1].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[1].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[1].set_xlabel("")
axs[1].set_ylabel("Contribute", fontsize=15)
axs[1].set_title("Experience optional")
axs[1].set_xticks([0, 1], ["not satisfy", "satisfy"],fontsize=14)
axs[1].set_yticks(axs[0].get_yticks())
plt.suptitle("Experience feature", fontsize=18)
plt.show()

# %% [markdown]
# ## fitness language

# %%
lang_basic_points = interpreter.build_dataframe_function("fitness_lang_basic")
lang_lvl_basic_points = interpreter.build_dataframe_function("fitness_lang_lvl_basic")
lang_bonus_points = interpreter.build_dataframe_function("fitness_lang_bonus")

_, axs = plt.subplots(ncols=3, figsize=(18, 5))

sns.barplot(x="x", y="y", data=lang_basic_points, palette="flare",hue="y", legend=False, width=0.3, ax=axs[0])
axs[0].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[0].set_yticks([*np.arange(-6, 4, 0.7)])
axs[0].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[0].set_xlabel("")
axs[0].set_ylabel("Contribute", fontsize=15)
axs[0].set_title("Language essential")
axs[0].set_xticks([0, 1, 2], ["0 satisfy", "1 satisfy", "2 satisfy"],fontsize=14)

sns.barplot(x="x", y="y", data=lang_lvl_basic_points, palette="flare",hue="y", legend=False, width=0.3, ax=axs[1])
axs[1].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[1].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[1].set_xlabel("")
axs[1].set_ylabel("Contribute", fontsize=15)
axs[1].set_title("Language level essential")
axs[1].set_xticks([0, 1, 2], ["0 level\nsatisfy", "1 level\nsatisfy", "2 level\nsatisfy"],fontsize=14)
axs[1].set_yticks(axs[0].get_yticks())


sns.barplot(x="x", y="y", data=lang_bonus_points, palette="flare", hue="y", legend=False,width=0.3, ax=axs[2])
axs[2].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[2].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[2].set_xlabel("")
axs[2].set_ylabel("Contribute", fontsize=15)
axs[2].set_title("Language optional")
axs[2].set_xticks([0, 1, 2], ["not satisfy", "satisfy\nwithout certificate", "satisfy"],fontsize=14)
axs[2].set_yticks(axs[0].get_yticks())

plt.suptitle("Language feature", fontsize=18)
plt.show()

# %% [markdown]
# ## fitness competences

# %%
comp_basic_points = interpreter.build_dataframe_function("fitness_comp_basic")
comp_basic_sim_points = interpreter.build_dataframe_function("fitness_comp_sim_basic")
comp_bonus_points = interpreter.build_dataframe_function("fitness_comp_bonus")
comp_bonus_sim_points = interpreter.build_dataframe_function("fitness_comp_sim_bonus")

_, axs = plt.subplots(ncols=2, figsize=(12, 5))

sns.barplot(x="x", y="y", data=comp_basic_points, palette="flare",hue=comp_basic_points.index, legend=False, width=0.3, ax=axs[0])
axs[0].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[0].set_yticks([*np.arange(-7, 6, 1)])
axs[0].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[0].set_xlabel("")
axs[0].set_ylabel("Contribute", fontsize=15)
axs[0].set_title("Competence essential")
axs[0].set_xticks([0, 1, 2, 3, 4, 5, 6], ["0%", "25%", "33%","50%", "66%", "75%","100%"],fontsize=14)

sns.barplot(x="x", y="y", data=comp_basic_sim_points, palette="flare",hue=comp_basic_sim_points.index, legend=False, width=0.3, ax=axs[1])
axs[1].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[1].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[1].set_xlabel("")
axs[1].set_ylabel("Contribute", fontsize=15)
axs[1].set_title("Competence(not matched) similarity essential")
axs[1].set_xticks([0, 1, 2, 3, 4], ["0%", "25%", "50%", "75%", "100%"],fontsize=14)
axs[1].set_yticks(axs[0].get_yticks())
plt.suptitle("Competence essential feature", fontsize=18)
plt.show()

_, axs = plt.subplots(ncols=2, figsize=(12, 5))


sns.barplot(x="x", y="y", data=comp_bonus_points, palette="flare",hue=comp_bonus_points.index, legend=False, width=0.3, ax=axs[0])
axs[0].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[0].set_yticks([*np.arange(-1.5, 7, 1)])
axs[0].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[0].set_xlabel("")
axs[0].set_ylabel("Contribute", fontsize=15)
axs[0].set_title("Competence optional")
axs[0].set_xticks([0, 1, 2, 3, 4], ["0%", "33%", "50%", "66%", "100%"])

sns.barplot(x="x", y="y", data=comp_bonus_sim_points, palette="flare",hue=comp_bonus_sim_points.index, legend=False, width=0.3, ax=axs[1])
axs[1].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[1].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[1].set_xlabel("")
axs[1].set_ylabel("Contribute", fontsize=15)
axs[1].set_title("Competence(not matched) similarity optional")
axs[1].set_xticks([0, 1, 2, 3, 4], ["0%", "25%", "50%", "75%", "100%"],fontsize=14)
axs[1].set_yticks(axs[0].get_yticks())

plt.suptitle("Competence optional feature", fontsize=18)
plt.show()

# %%
know_basic_points = interpreter.build_dataframe_function("fitness_know_basic")
know_basic_sim_points = interpreter.build_dataframe_function("fitness_know_sim_basic")
know_bonus_points = interpreter.build_dataframe_function("fitness_know_bonus")
know_bonus_sim_points = interpreter.build_dataframe_function("fitness_know_sim_bonus")


_, axs = plt.subplots(ncols=2, figsize=(12, 5))

sns.barplot(x="x", y="y", data=know_basic_points, palette="flare",hue=know_basic_points.index, legend=False, width=0.3, ax=axs[0])
axs[0].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[0].set_yticks([*np.arange(-7, 6, 0.5)])
axs[0].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[0].set_xlabel("")
axs[0].set_ylabel("Contribute", fontsize=15)
axs[0].set_title("Knowledge essential")
axs[0].set_xticks([0, 1, 2, 3, 4, 5, 6], ["0%", "25%", "33%","50%", "66%", "75%","100%"],fontsize=14)

sns.barplot(x="x", y="y", data=know_basic_sim_points, palette="flare",hue=know_basic_sim_points.index, legend=False, width=0.3, ax=axs[1])
axs[1].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[1].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[1].set_xlabel("")
axs[1].set_ylabel("Contribute", fontsize=15)
axs[1].set_title("Knowledge(not matched) similarity essential")
axs[1].set_xticks([0, 1, 2, 3, 4], ["0%", "25%", "50%", "75%", "100%"],fontsize=14)
axs[1].set_yticks(axs[0].get_yticks())
plt.suptitle("Knowledge essential feature", fontsize=18)
plt.show()

_, axs = plt.subplots(ncols=2, figsize=(12, 5))

sns.barplot(x="x", y="y", data=know_bonus_points, palette="flare",hue=know_bonus_points.index, legend=False, width=0.3, ax=axs[0])
axs[0].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[0].set_yticks([*np.arange(-1, 7, 0.5)])
axs[0].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[0].set_xlabel("")
axs[0].set_ylabel("Contribute", fontsize=15)
axs[0].set_title("Knowledge optional")
axs[0].set_xticks([0, 1, 2, 3, 4], ["0%", "33%", "50%", "66%", "100%"],fontsize=14)

sns.barplot(x="x", y="y", data=know_bonus_sim_points, palette="flare",hue=know_bonus_sim_points.index, legend=False, width=0.3, ax=axs[1])
axs[1].axhline(y=0, color="black", linestyle="-", linewidth=0.5)
axs[1].grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs[1].set_xlabel("")
axs[1].set_ylabel("Contribute", fontsize=15)
axs[1].set_title("Knowledge(not matched) similarity optional")
axs[1].set_xticks([0, 1, 2, 3, 4], ["0%", "25%", "50%", "75%", "100%"],fontsize=14)
# 1083                    0.25
# 1109                    0.25
# 1165                    0.25
# 1180                    0.25
# 1207                    0.00
# 1354                    0.25
# 1710                    0.25
# 1731                    0.25
# 1915                    0.00
# 2210                    0.25
# 2413                    0.25
# 2421                    0.25
# 2706                    0.25
# 2714                    0.25
# 2922                    0.25
# 3041                    0.25
# 3045                    0.25
# 3240                    0.25
# 3394                    0.25
# 3398                    0.25
# 3436                    0.00
# 3929                    0.25
# 4043                    0.25
# 4518                    0.25
# 4924                    0.25
# 5116                    0.25
# 5133                    0.25
# 5295                    0.25
#
# [37 rows x 22 columns]

# %%
candidate1 = np.expand_dims(job_offer.loc[169][5:].to_numpy(),0)
candidate2 = np.expand_dims(job_offer.loc[1710][5:].to_numpy(),0)
candidates = np.concatenate([candidate1, candidate2], axis=0)

# %%
score, contributes = interpreter.get_contribute(candidates)

# %%
contributes
# Out:
#                         Candidate0  Candidate1
# fitness_edu_basic         0.547987    0.547987
# fitness_edu_bonus        -0.727768   -0.727768
# fitness_city             -0.141206   -0.141206
# fitness_age               0.504181    0.504181
# fitness_exp_basic         4.693770   -3.150568
# fitness_exp_bonus        -0.360431   -0.360431
# fitness_lang_basic        2.612236   -5.043538
# fitness_lang_lvl_basic    2.605797   -3.784739
# fitness_lang_bonus        1.699492   -0.261033
# fitness_comp_basic       -0.692888   -6.051783
# fitness_comp_sim_basic    0.525497    0.525497
# fitness_comp_bonus       -0.348067   -0.348067
# fitness_comp_sim_bonus    0.422196   -0.897385
# fitness_know_basic        3.176475   -6.589710
# fitness_know_sim_basic   -0.815290    0.906752
# fitness_know_bonus       -0.853801   -0.853801
# fitness_know_sim_bonus    0.575992    0.575992

# %%
feature_names = list(matching_par["weight"].keys())

# %%
_, axs = plt.subplots(figsize=(10, 7), sharey=True)

sns.barplot(x="Candidate0", y=contributes.index, data=contributes, palette="crest", hue=contributes.index, legend=False, ax=axs)
axs.axvline(x=0, color="black", linestyle="-", linewidth=0.5)
axs.grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs.set_title("Candidate A",fontsize=18)
axs.set_ylabel("", fontsize=15)
axs.set_xlabel("Contribute", fontsize=15)
axs.set_yticks([*range(len(feature_names))],feature_names)
axs.set_xticks([*np.arange(-7, 5 + 1, 1)])

axs.tick_params(axis='both', labelsize=15)
plt.show()

# %%
_, axs = plt.subplots(figsize=(10, 7), sharey=True)

sns.barplot(x="Candidate1", y=contributes.index, data=contributes, palette="crest", hue=contributes.index, legend=False, ax=axs)
axs.axvline(x=0, color="black", linestyle="-", linewidth=0.5)
axs.grid(color='grey', linestyle='-.', linewidth=0.5, alpha=0.5)
axs.set_title("Candidate B",fontsize=18)
axs.set_ylabel("", fontsize=15)
axs.set_xlabel("Contribute", fontsize=15)
axs.set_yticks([*range(len(feature_names))],feature_names)
axs.set_xticks([*np.arange(-7, 5 + 1, 1)])
axs.tick_params(axis='both', labelsize=15)
plt.show()
